# %%
from sqlalchemy import text
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("postgresql://postgres:@localhost:5430/mafia_casino_db")

# %%
name = input('enter name')

with engine.connect() as connection:
    rows = connection.execute('SELECT * FROM user_login')

    for row in rows:
        names_in_db = row[1]
        if name == names_in_db:
            print("Login successful")
        else:
            name = input("Username Does not exist!, Please enter username!")
            psswrd = input("Create a new password")
            data = {'username': [name],
                    'password': [psswrd]}
            df = pd.DataFrame(data)
            df.to_sql('user_login', con=connection, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# DependentObjectsStillExist                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818                 if not evt_handled:
# -> 1819                     self.dialect.do_execute(
#    1820                         cursor, statement, parameters, context
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# DependentObjectsStillExist: cannot drop table user_login because other objects depend on it
# DETAIL:  constraint fk_casino_acc on table casino_account depends on table user_login
# constraint fk_details on table details depends on table user_login
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-41-a7b170319087> in <module>
#      14                     'password': [psswrd]}
#      15             df = pd.DataFrame(data)
# ---> 16             df.to_sql('user_login', con=connection, if_exists='replace')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404             dtype=dtype,
#    1405         )
# -> 1406         table.create()
#    1407
#    1408         from sqlalchemy import exc
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     738                 raise ValueError(f"Table '{self.name}' already exists.")
#     739             elif self.if_exists == "replace":
# --> 740                 self.pd_sql.drop_table(self.name, self.schema)
#     741                 self._execute_create()
#     742             elif self.if_exists == "append":
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in drop_table(self, table_name, schema)
#    1479         if self.has_table(table_name, schema):
#    1480             self.meta.reflect(only=[table_name], schema=schema)
# -> 1481             self.get_table(table_name, schema).drop()
#    1482             self.meta.clear()
#    1483
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in drop(self, bind, checkfirst)
#     974         if bind is None:
#     975             bind = _bind_or_error(self)
# --> 976         bind._run_ddl_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#     977
#     978     @util.deprecated(
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2128
#    2129         """
# -> 2130         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2131
#    2132     @util.deprecated(
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     522             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523             if meth:
# --> 524                 return meth(obj, **kw)
#     525
#     526     def iterate(self, obj):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in visit_table(self, table, drop_ok, _is_metadata_operation, _ignore_sequences)
#    1100         )
#    1101
# -> 1102         self.connection.execute(DropTable(table))
#    1103
#    1104         # traverse client side defaults which may refer to server-side
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1304             )
#    1305         else:
# -> 1306             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1307
#    1308     def _execute_function(self, func, multiparams, params, execution_options):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      78         self, connection, multiparams, params, execution_options
#      79     ):
# ---> 80         return connection._execute_ddl(
#      81             self, multiparams, params, execution_options
#      82         )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1396             dialect=dialect, schema_translate_map=schema_translate_map
#    1397         )
# -> 1398         ret = self._execute_context(
#    1399             dialect,
#    1400             dialect.execution_ctx_cls._init_ddl,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1860
#    1861         except BaseException as e:
# -> 1862             self._handle_dbapi_exception(
#    1863                 e, statement, parameters, cursor, context
#    1864             )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042             elif should_wrap:
# -> 2043                 util.raise_(
#    2044                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045                 )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                             break
#    1818                 if not evt_handled:
# -> 1819                     self.dialect.do_execute(
#    1820                         cursor, statement, parameters, context
#    1821                     )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# InternalError: (psycopg2.errors.DependentObjectsStillExist) cannot drop table user_login because other objects depend on it
# DETAIL:  constraint fk_casino_acc on table casino_account depends on table user_login
# constraint fk_details on table details depends on table user_login
# HINT:  Use DROP ... CASCADE to drop the dependent objects too.
#
# [SQL:
# DROP TABLE user_login]
# (Background on this error at: https://sqlalche.me/e/14/2j85)
